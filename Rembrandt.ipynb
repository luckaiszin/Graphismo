# %% [markdown]
# Este Projeto consiste em trabalhar com a arte da forma que um Cientista de Dados costuma lidar: através dos Gráficos
#
# Este será um tutorial de Matplotlib e Seaborn

# %% [markdown]
# Baseado nos projetos de:
# Prof. Luiz T. F. Eleno

# %%
import matplotlib.pyplot as plt

# %%
x = [0, 1, 3, 2, 3, 4]
y = [1, 3, 5, 1, 8, 3]

# %%
plt.figure()

plt.plot(x, y)

plt.show()

# %%
# Destacando os pontos

plt.figure()

plt.plot(x, y, 'o')

plt.show()

# %%
# Destacando os pontos

plt.figure()

plt.plot(x, y, '-o')

plt.show()

# %%
### Especificações:

# Formato: Tracejado
# Eixo X: de 0 até 5
# Eixo Y: de 0 até 10

## Titulo:

# Eixo X: Valores de x
# Eixo Y: Valores de f(x)

x = [0, 1, 3, 2, 3, 4]
y = [1, 3, 5, 1, 8, 3]

plt.figure()

plt.plot(x, y,'--o', label='medidas experimentais')

plt.xlim(0,5)
plt.ylim(0,10)

plt.xlabel('valores de $x$')  # veja que dá pra usar LaTeX!
plt.ylabel('valores de $f(x)$')

plt.legend()
plt.show()

plt.show()

# %% [markdown]
# ### Gráfico de uma função

# %%
import numpy as np

# %%
x = np.linspace(-np.pi, 2*np.pi, 201)
y = np.cos(x)

plt.figure()

plt.plot(x, y, label='$\cos(x)$')

plt.xlim(-np.pi,2*np.pi)
plt.ylim(-1.2, 1.2)

plt.xlabel('$x$')  # veja que dá pra usar LaTeX!
plt.ylabel('$\cos(x)$')

plt.axhline(y=0, color='k')  # eixo x
plt.axvline(x=0, color='k')  # eixo y

plt.legend()
plt.show()

# %% [markdown]
# ### Gráfico com barras de erros

# %%
x = [0, 1, 3, 2, 3, 4]
y = [1, 3, 5, 1, 8, 3]

desvio = .5

plt.figure()

plt.errorbar(x, y, yerr=desvio,fmt = 'ro', ecolor='black', linestyle=None, capsize=2, label='experimental')

plt.legend()
plt.show()

# %% [markdown]
# #### Desvio com porcentagem

# %%
x = [0, 1, 3, 2, 3, 4]
y = [1, 3, 5, 5, 8, 3]

desvio = .1 * np.array(y)

plt.figure()

plt.errorbar(x, y, yerr=desvio,fmt = 'ro', ecolor='black', linestyle=None, capsize=2, label='experimental')

plt.legend()
plt.show()

# %% [markdown]
# #### Desvio variável

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [0, 1, 3, 2, 3, 4]
y = [1, 3, 5, 1, 8, 3]

desvio = [.4, .2, .3, .4, 1, .5]

plt.figure()

plt.errorbar(x, y, yerr=desvio, fmt='ro', ecolor='black', linestyle=None, capsize=2, label='experimental')

plt.legend()
plt.show()
